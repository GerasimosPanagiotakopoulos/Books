# %%
import datetime as dt
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

import matplotlib.ticker as tkr
pd.options.mode.chained_assignment = None
pd.set_option('display.max_columns', None)

pd.set_option('display.width', 220)

# %%
data_full = pd.read_csv('../data/google_books_1299.csv')
data_full.drop(columns=['Unnamed: 0'], inplace=True)
data_full.head()
# Out:
#                                               title          author  rating voters   price currency                                        description                    publisher  page_count  \
# 0                        Attack on Titan: Volume 13  Hajime Isayama     4.6    428   43.28      SAR  NO SAFE PLACE LEFT At great cost to the Garris...              Kodansha Comics         192
# 1  Antiques Roadkill: A Trash 'n' Treasures Mystery   Barbara Allan     3.3     23   26.15      SAR  Determined to make a new start in her quaint h...  Kensington Publishing Corp.         288
# 2                    The Art of Super Mario Odyssey        Nintendo     3.9      9  133.85      SAR  Take a globetrotting journey all over the worl...            Dark Horse Comics         368
# 3    Getting Away Is Deadly: An Ellie Avery Mystery     Sara Rosett     4.0     10   26.15      SAR  With swollen feet and swelling belly, pregnant...  Kensington Publishing Corp.         320
# 4         The Painted Man (The Demon Cycle, Book 1)  Peter V. Brett     4.5    577   28.54      SAR  The stunning debut fantasy novel from author P...             HarperCollins UK         544
#
#                                              generes           ISBN language published_date
# 0                                               none  9781612626864  English   Jul 31, 2014
# 1  Fiction , Mystery &amp, Detective , Cozy , Gen...  9780758272799  English    Jul 1, 2007
# 2    Games &amp, Activities , Video &amp, Electronic  9781506713816  English    Nov 5, 2019
# 3                                               none  9781617734076  English    Mar 1, 2009
# 4                   Fiction , Fantasy , Dark Fantasy  9780007287758  English    Jan 8, 2009
